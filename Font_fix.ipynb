# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# Works!
def set_params():
      plt.rcParams['mathtext.fontset'] = 'custom'
      plt.rcParams['font.size'] = 25
      plt.rcParams['mathtext.rm'] = 'Times New Roman'
      plt.rcParams['mathtext.it'] = 'Times New Roman:italic'
      plt.rcParams['mathtext.bf'] = 'Times New Roman:bold'
      plt.rcParams['font.family'] = 'Times New Roman'
      # plt.rcParams['mathtext.rm'] = 'Arial'
      # plt.rcParams['mathtext.it'] = 'Arial:italic'
      # plt.rcParams['mathtext.bf'] = 'Arial:bold'
      # plt.rcParams['font.family'] = 'Arial'

def plot():
      rows, cols = 3,3
      fig, axs = plt.subplots(rows,cols,constrained_layout=True)
      inches = 9.5
      inches_factor = inches/np.max((rows,cols))
      fig.set_size_inches(cols*inches_factor,rows*inches_factor)
      axs = axs.flatten()
      text = "t0 $t$"
      image_array = np.random.rand(15,100,100)
      vmin, vmax = np.min(image_array), np.max(image_array)
      for i in range(rows*cols):
            if i < len(image_array):
                  axs[i].imshow(image_array[i], cmap='Greys_r', vmin=vmin, vmax=vmax) 
                  axs[i].text(5,10,text+str(i), color='w', bbox=dict(facecolor='gray', edgecolor='none', pad=1.0, alpha= 0.7))
            axs[i].set_axis_off()  

set_params()
plot()
